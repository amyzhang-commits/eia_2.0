# %% [markdown]
# # EIA Thermoelectric Cooling Data (2014 - 2024)
#
# # 01_data_ingestion
#
# **Author:** Amy Zhang
# **AI Collaborators:** ChatGPT, Claude Code, Perplexity AI
# **Date:** January 2026
#
# ## Table of Contents
#   1. **Import Libraries**
#   2. **Integrate EIA Thermoelectric Cooling Dataset**
#      2a) *Quick Profile of Sparse Categorical Columns*
#      2b) *Interpretation & Decision*
#   4. **Preliminary Dataset Polish for SQL Import**
#      3a) *Tackle Column Renaming*
#      3b) *Tackle Dtypes*
#   6. **Persist SQL-Ready 'Ground Truth' Dataset**

# %% [markdown]
# # 1. Import Libraries

# %%
# 1. Auto-reload external modules (during development)
# %load_ext autoreload
# %autoreload 2

# 2. Standard library
import os
import re

# 3. Third party  
import numpy as np
import pandas as pd

# %% [markdown]
# # 2. Integrate  EIA Thermoelectric Cooling Dataset

# %%
from scripts.dataset_pipeline import datasets_overview, merge_folder_files

# %%
# Test fallback
datasets_overview()
# Out:
# 🔍 PHASE 1: DATASET OVERVIEW
#    Target folder: /Users/amyzhang/Documents/Projects_2026/eia_2.0/datasets_thermoelectric
#    This step inspects schemas and estimates memory usage only.
#    No files are merged in Phase 1.
#
#    • Cooling_Boiler_Generator_Data_Detail_2022.xlsx | columns: 70 | header row: 2 | rows: 83,293 | estimated size: ~0.25 GB
#    • Cooling_Boiler_Generator_Data_Detail_2023.xlsx | columns: 70 | header row: 2 | rows: 82,933 | estimated size: ~0.24 GB
#    • cooling_detail_2015.xlsx | columns: 70 | header row: 2 | rows: 83,209 | estimated size: ~0.13 GB
#    • Cooling_Boiler_Generator_Data_Detail_2024.xlsx | columns: 70 | header row: 2 | rows: 82,897 | estimated size: ~0.24 GB
#    • cooling_detail_2019.xlsx | columns: 70 | header row: 2 | rows: 84,325 | estimated size: ~0.23 GB
#    • cooling_detail_2018.xlsx | columns: 70 | header row: 2 | rows: 84,457 | estimated size: ~0.24 GB
#    • cooling_detail_2014.xlsx | columns: 70 | header row: 2 | rows: 83,017 | estimated size: ~0.13 GB
#    • cooling_detail_2017.xlsx | columns: 70 | header row: 2 | rows: 83,089 | estimated size: ~0.23 GB
#    • cooling_detail_2020.xlsx | columns: 70 | header row: 2 | rows: 84,253 | estimated size: ~0.23 GB
#    • cooling_detail_2016.xlsx | columns: 70 | header row: 2 | rows: 82,477 | estimated size: ~0.13 GB
#    • Cooling_Boiler_Generator_Data_Detail_2021.xlsx | columns: 70 | header row: 2 | rows: 83,497 | estimated size: ~0.25 GB
#
# 📊 SCHEMA SUMMARY
#    Unique columns across all files: 70
#
# 💾 MEMORY SUMMARY
#    Estimated combined dataset size: ~2.30 GB
#    Detected system RAM:            ~17.18 GB
#
# ✅ MEMORY RECOMMENDATION
#    Direct merge is likely safe for this dataset:
#       merge_folder_files(chunk_size=None)
#
# 🗄️  STORAGE RECOMMENDATION
#    Detected a wide schema with 70 columns.
#    Consider persisting to a database or using a columnar store.
#    Example: prepare for SQL ingestion with a dedicated utility.
#
# ✅ PHASE 1 COMPLETE
#    Review the above summary before running the merge step.

# %%
df = merge_folder_files(save=True)
# Out:
# 🔗 PHASE 2: MERGE
#    Source folder: /Users/amyzhang/Documents/Projects_2026/eia_2.0/datasets_thermoelectric
#    Reading files into memory as full DataFrames.
# Merging files: 100%|████████████████████████████| 11/11 [02:52<00:00, 15.67s/it]
# 📐 Merged DataFrame shape: (917436, 70)
# ✅ Files merged: 11 of 11
#
# 🔟 TOP 10 COLUMNS WITH MISSING VALUES
#
#                                                                           Absent Count  Absent Percentage
# \n.1                                                                            917436         100.000000
# \n                                                                              917436         100.000000
# 860 Cooling Type 2                                                              894432          97.492577
# Generator Duct Burners?                                                         745188          81.225066
# Water Discharge Name                                                            257244          28.039449
# Number Operable Cooling Systems                                                 248700          27.108158
# Number Operable Boilers                                                         248700          27.108158
# Number Operable Generators                                                      248700          27.108158
# Gross Generation Associated with Single Shaft Combined Cycle Units (MWh)        247278          26.953161
# Fuel Consumption from Single Shaft Combined Cycle Units (MMBTU)                 247276          26.952943
#
# 💾 Merged CSV saved to: /Users/amyzhang/Documents/Projects_2026/eia_2.0/datasets_merged/merged_datasets_thermoelectric_20260208_114711.csv

# %%
# Drop columns that are 100% absent/empty values
df.drop(['\n.1', '\n'], axis=1, inplace=True)

# %% [markdown]
# ### 2a) Quick Profile of Sparse Categorical Columns

# %%
# Investigate unique values for categorical columns with nearly 100% absent/empty values
print(df['860 Cooling Type 2'].value_counts(dropna=False))
print("\n")
print(df['Generator Duct Burners?'].value_counts(dropna=False))
# Out:
# 860 Cooling Type 2
# NaN    894432
# RI      10512
# HT       6036
# RC       2604
# ON       2112
# OT       1260
# OC        348
# RF         84
# HRI        48
# Name: count, dtype: int64
#
#
# Generator Duct Burners?
# NaN    745188
# Y      123888
# N       48360
# Name: count, dtype: int64

# %%
print(df['860 Cooling Type 1'].value_counts(dropna=False))
# Out:
# 860 Cooling Type 1
# (RI) Recirculate: Induced Draft      450420
# (ON) Once through No Cool Pond       226020
# NaN                                   77700
# (RC) Recirculate: Cooling Pond        57456
# (DC) Dry Cooling                      51060
# (RN) Recirculate: Natural Draft       31608
# (OC) Once through with Cool Pond      13464
# (RF) Recirculate: Forced Draft         3900
# (OT) Other                             3144
# (HRI) Hybrid: Dry / Induced Draft      2664
# Name: count, dtype: int64

# %% [markdown]
# ### 2b) Interpretation & Decision
#
# - Although `860 Cooling Type 2` and `Generator Duct Burners?` are sparse, the non-null values represent meaningful operational characteristics. Retained for now; final decisions after granularity is established.
#
# - `860 Cooling Type 2` contains shorthand codes (likely mapping to `860 Cooling Type 1`). Remapping postponed - SQL lookup tables will handle human-readable labels.
#
# **TL;DR:** Retain both columns. Postpone remapping.

# %% [markdown]
# # 3. Preliminary Dataset Polish for SQL Import
#
# ### Why SQL?
#
#   1. **Flexible querying** - Wide schema (70 cols) benefits from views/derived tables without repeated Python transforms
#   2. **Validation environment** - Secondary place for sanity checks during iterative cleaning
#   3. **Disk-based** - Queries pull only needed data; Python reloads full dataset every session

# %%
from scripts.sql_pipeline import schema_preview, sql_prep_columns, dtype_audit, apply_sql_dtypes

# %%
schema_preview(df)
# Out:
# 🧬 Full Column Schema (name → dtype):
#
#                                                                             dtype
# \n \n \n \n \n \nUtility ID                                                 int64
# State                                                                      object
# Plant Code                                                                  int64
# Plant Name                                                                 object
# Year                                                                        int64
# Month                                                                       int64
# Generator ID                                                               object
# Boiler ID                                                                  object
# Cooling ID                                                                 object
# Generator Primary Technology                                               object
# Summer Capacity of Steam Turbines (MW)                                     object
# Gross Generation from Steam Turbines (MWh)                                 object
# Net Generation from Steam Turbines (MWh)                                   object
# Summer Capacity Associated with Single Shaft Combined Cycle Units (MW)     object
# Gross Generation Associated with Single Shaft Combined Cycle Units (MWh)   object
# Net Generation Associated with Single Shaft Combined Cycle Units (MWh)     object
# Summer Capacity Associated with Combined Cycle Gas Turbines (MW)           object
# Gross Generation Associated with Combined Cycle Gas Turbines (MWh)         object
# Net Generation Associated with Combined Cycle Gas Turbines (MWh)           object
# Fuel Consumption from All Fuel Types (MMBTU)                               object
# Fuel Consumption from Steam Turbines (MMBTU)                               object
# Fuel Consumption from Single Shaft Combined Cycle Units (MMBTU)            object
# Fuel Consumption from Combined Cycle Gas Turbines (MMBTU)                  object
# Coal Consumption (MMBTU)                                                   object
# Natural Gas Consumption (MMBTU)                                            object
# Petroleum Consumption (MMBTU)                                              object
# Biomass Consumption (MMBTU)                                                object
# Other Gas Consumption (MMBTU)                                              object
# Other Fuel Consumption (MMBTU)                                             object
# Water Withdrawal Volume (Million Gallons)                                  object
# Water Consumption Volume (Million Gallons)                                 object
# Water Withdrawal Intensity Rate (Gallons / MWh)                            object
# Water Consumption Intensity Rate (Gallons / MWh)                           object
# Water Withdrawal Rate per Fuel Consumption (Gallons / MMBTU)               object
# Water Consumption Rate per Fuel Consumption (Gallons / MMBTU)              object
# Cooling Unit Hours in Service                                              object
# Average Distance of Water Intake Below Water Surface (Feet)                object
# 860 Cooling Type 1                                                         object
# 860 Cooling Type 2                                                         object
# 923 Cooling Type                                                           object
# Cooling System Type                                                        object
# Water Type                                                                 object
# Water Source                                                               object
# Water Source Name                                                          object
# Water Discharge Name                                                       object
# Generator Status                                                           object
# Generator Inservice Month                                                  object
# Generator Inservice Year                                                   object
# Generator Retirement Month                                                 object
# Generator Retirement Year                                                  object
# Boiler Status                                                              object
# Boiler Inservice Month                                                     object
# Boiler Inservice Year                                                      object
# Boiler Retirement Month                                                    object
# Boiler Retirement Year                                                     object
# Cooling Status                                                             object
# Cooling Inservice Month                                                    object
# Cooling Inservice Year                                                     object
# Combined Heat and Power Generator?                                         object
# Generator Primary Energy Source Code                                       object
# Generator Prime Mover Code                                                 object
# Generator Duct Burners?                                                    object
# Sector                                                                     object
# Steam Plant Type                                                          float64
# Number Operable Generators                                                 object
# Number Operable Boilers                                                    object
# Number Operable Cooling Systems                                            object
# Relationship Type                                                          object
#
# 💾 Missingness audit saved to: /Users/amyzhang/Documents/Projects_2026/eia_2.0/datasets_merged/schema_missingness_audit_20260208_114731.csv
#                                                       dtype  total_rows  \
# column
# \n \n \n \n \n \nUtility ID                           int64      917436
# State                                                object      917436
# Plant Code                                            int64      917436
# Plant Name                                           object      917436
# Year                                                  int64      917436
# Month                                                 int64      917436
# Generator ID                                         object      917436
# Boiler ID                                            object      917436
# Cooling ID                                           object      917436
# Generator Primary Technology                         object      917436
# Summer Capacity of Steam Turbines (MW)               object      917436
# Gross Generation from Steam Turbines (MWh)           object      917436
# Net Generation from Steam Turbines (MWh)             object      917436
# Summer Capacity Associated with Single Shaft Co...   object      917436
# Gross Generation Associated with Single Shaft C...   object      917436
# Net Generation Associated with Single Shaft Com...   object      917436
# Summer Capacity Associated with Combined Cycle ...   object      917436
# Gross Generation Associated with Combined Cycle...   object      917436
# Net Generation Associated with Combined Cycle G...   object      917436
# Fuel Consumption from All Fuel Types (MMBTU)         object      917436
# Fuel Consumption from Steam Turbines (MMBTU)         object      917436
# Fuel Consumption from Single Shaft Combined Cyc...   object      917436
# Fuel Consumption from Combined Cycle Gas Turbin...   object      917436
# Coal Consumption (MMBTU)                             object      917436
# Natural Gas Consumption (MMBTU)                      object      917436
# Petroleum Consumption (MMBTU)                        object      917436
# Biomass Consumption (MMBTU)                          object      917436
# Other Gas Consumption (MMBTU)                        object      917436
# Other Fuel Consumption (MMBTU)                       object      917436
# Water Withdrawal Volume (Million Gallons)            object      917436
# Water Consumption Volume (Million Gallons)           object      917436
# Water Withdrawal Intensity Rate (Gallons / MWh)      object      917436
# Water Consumption Intensity Rate (Gallons / MWh)     object      917436
# Water Withdrawal Rate per Fuel Consumption (Gal...   object      917436
# Water Consumption Rate per Fuel Consumption (Ga...   object      917436
# Cooling Unit Hours in Service                        object      917436
# Average Distance of Water Intake Below Water Su...   object      917436
# 860 Cooling Type 1                                   object      917436
# 860 Cooling Type 2                                   object      917436
# 923 Cooling Type                                     object      917436
# Cooling System Type                                  object      917436
# Water Type                                           object      917436
# Water Source                                         object      917436
# Water Source Name                                    object      917436
# Water Discharge Name                                 object      917436
# Generator Status                                     object      917436
# Generator Inservice Month                            object      917436
# Generator Inservice Year                             object      917436
# Generator Retirement Month                           object      917436
# Generator Retirement Year                            object      917436
# Boiler Status                                        object      917436
# Boiler Inservice Month                               object      917436
# Boiler Inservice Year                                object      917436
# Boiler Retirement Month                              object      917436
# Boiler Retirement Year                               object      917436
# Cooling Status                                       object      917436
# Cooling Inservice Month                              object      917436
# Cooling Inservice Year                               object      917436
# Combined Heat and Power Generator?                   object      917436
# Generator Primary Energy Source Code                 object      917436
# Generator Prime Mover Code                           object      917436
# Generator Duct Burners?                              object      917436
# Sector                                               object      917436
# Steam Plant Type                                    float64      917436
# Number Operable Generators                           object      917436
# Number Operable Boilers                              object      917436
# Number Operable Cooling Systems                      object      917436
# Relationship Type                                    object      917436
#
#                                                     null_nan  empty_whitespace
# column
# \n \n \n \n \n \nUtility ID                                0                 0
# State                                                     24                 0
# Plant Code                                                 0                 0
# Plant Name                                                24                 0
# Year                                                       0                 0
# Month                                                      0                 0
# Generator ID                                             396                 0
# Boiler ID                                                156                 0
# Cooling ID                                                24                 0
# Generator Primary Technology                             396                 0
# Summer Capacity of Steam Turbines (MW)                 98244            275928
# Gross Generation from Steam Turbines (MWh)            131595            393498
# Net Generation from Steam Turbines (MWh)              135269            404835
# Summer Capacity Associated with Single Shaft Co...    246792            662544
# Gross Generation Associated with Single Shaft C...    247278            663885
# Net Generation Associated with Single Shaft Com...    247271            663889
# Summer Capacity Associated with Combined Cycle ...    160956            413040
# Gross Generation Associated with Combined Cycle...    169726            419885
# Net Generation Associated with Combined Cycle G...    180428            444241
# Fuel Consumption from All Fuel Types (MMBTU)           49734            143698
# Fuel Consumption from Steam Turbines (MMBTU)          131450            395460
# Fuel Consumption from Single Shaft Combined Cyc...    247276            664817
# Fuel Consumption from Combined Cycle Gas Turbin...    168648            421497
# Coal Consumption (MMBTU)                              192082            557981
# Natural Gas Consumption (MMBTU)                        80744            188566
# Petroleum Consumption (MMBTU)                         177143            501543
# Biomass Consumption (MMBTU)                           231874            622847
# Other Gas Consumption (MMBTU)                         235532            630407
# Other Fuel Consumption (MMBTU)                        238239            643612
# Water Withdrawal Volume (Million Gallons)              81336            229928
# Water Consumption Volume (Million Gallons)             92234            257251
# Water Withdrawal Intensity Rate (Gallons / MWh)       229895            630091
# Water Consumption Intensity Rate (Gallons / MWh)      231658            633927
# Water Withdrawal Rate per Fuel Consumption (Gal...    230932            632559
# Water Consumption Rate per Fuel Consumption (Ga...    232677            636339
# Cooling Unit Hours in Service                          61636            159612
# Average Distance of Water Intake Below Water Su...    116592            308832
# 860 Cooling Type 1                                     77700                 0
# 860 Cooling Type 2                                    894432                 0
# 923 Cooling Type                                      207887                 0
# Cooling System Type                                    76896                 0
# Water Type                                            133836                 0
# Water Source                                          134064                 0
# Water Source Name                                     130716                 0
# Water Discharge Name                                  257244                 0
# Generator Status                                         396                 0
# Generator Inservice Month                               4884              8196
# Generator Inservice Year                                4884              8196
# Generator Retirement Month                            217596            553920
# Generator Retirement Year                             217596            553920
# Boiler Status                                            372                 0
# Boiler Inservice Month                                 20844             44880
# Boiler Inservice Year                                  20856             44880
# Boiler Retirement Month                               168432            431736
# Boiler Retirement Year                                168228            431580
# Cooling Status                                         76980                 0
# Cooling Inservice Month                                23520             55188
# Cooling Inservice Year                                 23520             55188
# Combined Heat and Power Generator?                       804                 0
# Generator Primary Energy Source Code                     396                 0
# Generator Prime Mover Code                               396                 0
# Generator Duct Burners?                               745188                 0
# Sector                                                   879                 0
# Steam Plant Type                                          24                 0
# Number Operable Generators                            248700            668736
# Number Operable Boilers                               248700            668736
# Number Operable Cooling Systems                       248700            668736
# Relationship Type                                          0                 0

# %% [markdown]
# ### 3a) Tackle Column Renaming

# %%
sql_df = sql_prep_columns(df)
# Out:
# 🧬 Final cleaned column names:
#    utility_id, state, plant_code, plant_name, year, month, generator_id, boiler_id, cooling_id, generator_primary_technology, summer_capacity_of_steam_turbines_mw, gross_generation_from_steam_turbines_mwh, net_generation_from_steam_turbines_mwh, summer_capacity_associated_with_single_shaft_combined_cycle_units_mw, gross_generation_associated_with_single_shaft_combined_cycle_units_mwh, net_generation_associated_with_single_shaft_combined_cycle_units_mwh, summer_capacity_associated_with_combined_cycle_gas_turbines_mw, gross_generation_associated_with_combined_cycle_gas_turbines_mwh, net_generation_associated_with_combined_cycle_gas_turbines_mwh, fuel_consumption_from_all_fuel_types_mmbtu, fuel_consumption_from_steam_turbines_mmbtu, fuel_consumption_from_single_shaft_combined_cycle_units_mmbtu, fuel_consumption_from_combined_cycle_gas_turbines_mmbtu, coal_consumption_mmbtu, natural_gas_consumption_mmbtu, petroleum_consumption_mmbtu, biomass_consumption_mmbtu, other_gas_consumption_mmbtu, other_fuel_consumption_mmbtu, water_withdrawal_volume_million_gallons, water_consumption_volume_million_gallons, water_withdrawal_intensity_rate_gallons__mwh, water_consumption_intensity_rate_gallons__mwh, water_withdrawal_rate_per_fuel_consumption_gallons__mmbtu, water_consumption_rate_per_fuel_consumption_gallons__mmbtu, cooling_unit_hours_in_service, average_distance_of_water_intake_below_water_surface_feet, cooling_type_1_860, cooling_type_2_860, cooling_type_923, cooling_system_type, water_type, water_source, water_source_name, water_discharge_name, generator_status, generator_inservice_month, generator_inservice_year, generator_retirement_month, generator_retirement_year, boiler_status, boiler_inservice_month, boiler_inservice_year, boiler_retirement_month, boiler_retirement_year, cooling_status, cooling_inservice_month, cooling_inservice_year, combined_heat_and_power_generator, generator_primary_energy_source_code, generator_prime_mover_code, generator_duct_burners, sector, steam_plant_type, number_operable_generators, number_operable_boilers, number_operable_cooling_systems, relationship_type

# %% [markdown]
# ### 3b) Tackle Dtypes

# %%
audit_df = dtype_audit(sql_df)
audit_df
# Out:
#                                                column inferred_dtype  \
# 0                                          utility_id          int64
# 1                                               state         object
# 2                                          plant_code          int64
# 3                                          plant_name         object
# 4                                                year          int64
# 5                                               month          int64
# 6                                        generator_id         object
# 7                                           boiler_id         object
# 8                                          cooling_id         object
# 9                        generator_primary_technology         object
# 10               summer_capacity_of_steam_turbines_mw         object
# 11           gross_generation_from_steam_turbines_mwh         object
# 12             net_generation_from_steam_turbines_mwh         object
# 13  summer_capacity_associated_with_single_shaft_c...         object
# 14  gross_generation_associated_with_single_shaft_...         object
# 15  net_generation_associated_with_single_shaft_co...         object
# 16  summer_capacity_associated_with_combined_cycle...         object
# 17  gross_generation_associated_with_combined_cycl...         object
# 18  net_generation_associated_with_combined_cycle_...         object
# 19         fuel_consumption_from_all_fuel_types_mmbtu         object
# 20         fuel_consumption_from_steam_turbines_mmbtu         object
# 21  fuel_consumption_from_single_shaft_combined_cy...         object
# 22  fuel_consumption_from_combined_cycle_gas_turbi...         object
# 23                             coal_consumption_mmbtu         object
# 24                      natural_gas_consumption_mmbtu         object
# 25                        petroleum_consumption_mmbtu         object
# 26                          biomass_consumption_mmbtu         object
# 27                        other_gas_consumption_mmbtu         object
# 28                       other_fuel_consumption_mmbtu         object
# 29            water_withdrawal_volume_million_gallons         object
# 30           water_consumption_volume_million_gallons         object
# 31       water_withdrawal_intensity_rate_gallons__mwh         object
# 32      water_consumption_intensity_rate_gallons__mwh         object
# 33  water_withdrawal_rate_per_fuel_consumption_gal...         object
# 34  water_consumption_rate_per_fuel_consumption_ga...         object
# 35                      cooling_unit_hours_in_service         object
# 36  average_distance_of_water_intake_below_water_s...         object
# 37                                 cooling_type_1_860         object
# 38                                 cooling_type_2_860         object
# 39                                   cooling_type_923         object
# 40                                cooling_system_type         object
# 41                                         water_type         object
# 42                                       water_source         object
# 43                                  water_source_name         object
# 44                               water_discharge_name         object
# 45                                   generator_status         object
# 46                          generator_inservice_month         object
# 47                           generator_inservice_year         object
# 48                         generator_retirement_month         object
# 49                          generator_retirement_year         object
# 50                                      boiler_status         object
# 51                             boiler_inservice_month         object
# 52                              boiler_inservice_year         object
# 53                            boiler_retirement_month         object
# 54                             boiler_retirement_year         object
# 55                                     cooling_status         object
# 56                            cooling_inservice_month         object
# 57                             cooling_inservice_year         object
# 58                  combined_heat_and_power_generator         object
# 59               generator_primary_energy_source_code         object
# 60                         generator_prime_mover_code         object
# 61                             generator_duct_burners         object
# 62                                             sector         object
# 63                                   steam_plant_type        float64
# 64                         number_operable_generators         object
# 65                            number_operable_boilers         object
# 66                    number_operable_cooling_systems         object
# 67                                  relationship_type         object
#
#    suggested_dtype  numeric_parseable_%
# 0          INTEGER               100.00
# 1             TEXT                 0.00
# 2          INTEGER               100.00
# 3             TEXT                 0.00
# 4          INTEGER               100.00
# 5          INTEGER               100.00
# 6             TEXT                39.19
# 7             TEXT                38.27
# 8             TEXT                32.14
# 9             TEXT                 0.00
# 10           FLOAT               100.00
# 11           FLOAT               100.00
# 12           FLOAT               100.00
# 13           FLOAT               100.00
# 14           FLOAT               100.00
# 15           FLOAT               100.00
# 16           FLOAT               100.00
# 17           FLOAT               100.00
# 18           FLOAT               100.00
# 19           FLOAT               100.00
# 20           FLOAT               100.00
# 21           FLOAT               100.00
# 22           FLOAT               100.00
# 23           FLOAT               100.00
# 24           FLOAT               100.00
# 25           FLOAT               100.00
# 26           FLOAT               100.00
# 27           FLOAT               100.00
# 28           FLOAT               100.00
# 29           FLOAT               100.00
# 30           FLOAT               100.00
# 31           FLOAT               100.00
# 32           FLOAT               100.00
# 33           FLOAT               100.00
# 34           FLOAT               100.00
# 35         INTEGER               100.00
# 36           FLOAT               100.00
# 37            TEXT                 0.00
# 38            TEXT                 0.00
# 39            TEXT                 0.00
# 40            TEXT                 0.00
# 41            TEXT                 0.00
# 42            TEXT                 0.00
# 43            TEXT                 0.00
# 44            TEXT                 0.00
# 45            TEXT                 0.00
# 46         INTEGER               100.00
# 47         INTEGER               100.00
# 48         INTEGER               100.00
# 49         INTEGER               100.00
# 50            TEXT                 0.00
# 51         INTEGER               100.00
# 52         INTEGER               100.00
# 53         INTEGER               100.00
# 54         INTEGER               100.00
# 55            TEXT                 0.00
# 56         INTEGER               100.00
# 57         INTEGER               100.00
# 58            TEXT                 0.00
# 59            TEXT                 0.00
# 60            TEXT                 0.00
# 61            TEXT                 0.00
# 62            TEXT                 0.00
# 63         INTEGER               100.00
# 64            TEXT                 0.00
# 65            TEXT                 0.00
# 66            TEXT                 0.00
# 67            TEXT                 0.00

# %% [markdown]
# ## Quick Profile of 'number_operable_' Columns
# Examining values to identify why our type inference function is treating these numeric columns as text

# %%
# Investigate unique values for 'number_operable_' columns
print(sql_df['number_operable_generators'].value_counts(dropna=False))
print("\n")
print(sql_df['number_operable_boilers'].value_counts(dropna=False))
print("\n")
print(sql_df['number_operable_cooling_systems'].value_counts(dropna=False))
# Out:
# number_operable_generators
# not_reported    668736
# NaN             248700
# Name: count, dtype: int64
#
#
# number_operable_boilers
# not_reported    668736
# NaN             248700
# Name: count, dtype: int64
#
#
# number_operable_cooling_systems
# not_reported    668736
# NaN             248700
# Name: count, dtype: int64

# %% [markdown]
# ## Interpretation & Decision
#
# The 'number_operable_' columns contain no actual data. While the attribute name suggests plant-level granularity, other features—generator, boiler, and cooling IDs—indicate a unit-level granularity.
#
# **These columns will be dropped**, as they are likely artifacts from an internal cross-survey merge and provide no meaningful information for analysis.

# %%
sql_df.drop(['number_operable_generators', 'number_operable_boilers', 'number_operable_cooling_systems'], axis=1, inplace=True)

# %%
sql_df = apply_sql_dtypes(sql_df, audit_df)
# Out:
# ✅ Converted 65 columns

# %%
# Confirm dtype conversion
sql_df.dtypes
# Out:
# utility_id                                                                         Int64
# state                                                                     string[python]
# plant_code                                                                         Int64
# plant_name                                                                string[python]
# year                                                                               Int64
# month                                                                              Int64
# generator_id                                                              string[python]
# boiler_id                                                                 string[python]
# cooling_id                                                                string[python]
# generator_primary_technology                                              string[python]
# summer_capacity_of_steam_turbines_mw                                             Float64
# gross_generation_from_steam_turbines_mwh                                         Float64
# net_generation_from_steam_turbines_mwh                                           Float64
# summer_capacity_associated_with_single_shaft_combined_cycle_units_mw             Float64
# gross_generation_associated_with_single_shaft_combined_cycle_units_mwh           Float64
# net_generation_associated_with_single_shaft_combined_cycle_units_mwh             Float64
# summer_capacity_associated_with_combined_cycle_gas_turbines_mw                   Float64
# gross_generation_associated_with_combined_cycle_gas_turbines_mwh                 Float64
# net_generation_associated_with_combined_cycle_gas_turbines_mwh                   Float64
# fuel_consumption_from_all_fuel_types_mmbtu                                       Float64
# fuel_consumption_from_steam_turbines_mmbtu                                       Float64
# fuel_consumption_from_single_shaft_combined_cycle_units_mmbtu                    Float64
# fuel_consumption_from_combined_cycle_gas_turbines_mmbtu                          Float64
# coal_consumption_mmbtu                                                           Float64
# natural_gas_consumption_mmbtu                                                    Float64
# petroleum_consumption_mmbtu                                                      Float64
# biomass_consumption_mmbtu                                                        Float64
# other_gas_consumption_mmbtu                                                      Float64
# other_fuel_consumption_mmbtu                                                     Float64
# water_withdrawal_volume_million_gallons                                          Float64
# water_consumption_volume_million_gallons                                         Float64
# water_withdrawal_intensity_rate_gallons__mwh                                     Float64
# water_consumption_intensity_rate_gallons__mwh                                    Float64
# water_withdrawal_rate_per_fuel_consumption_gallons__mmbtu                        Float64
# water_consumption_rate_per_fuel_consumption_gallons__mmbtu                       Float64
# cooling_unit_hours_in_service                                                      Int64
# average_distance_of_water_intake_below_water_surface_feet                        Float64
# cooling_type_1_860                                                        string[python]
# cooling_type_2_860                                                        string[python]
# cooling_type_923                                                          string[python]
# cooling_system_type                                                       string[python]
# water_type                                                                string[python]
# water_source                                                              string[python]
# water_source_name                                                         string[python]
# water_discharge_name                                                      string[python]
# generator_status                                                          string[python]
# generator_inservice_month                                                          Int64
# generator_inservice_year                                                           Int64
# generator_retirement_month                                                         Int64
# generator_retirement_year                                                          Int64
# boiler_status                                                             string[python]
# boiler_inservice_month                                                             Int64
# boiler_inservice_year                                                              Int64
# boiler_retirement_month                                                            Int64
# boiler_retirement_year                                                             Int64
# cooling_status                                                            string[python]
# cooling_inservice_month                                                            Int64
# cooling_inservice_year                                                             Int64
# combined_heat_and_power_generator                                         string[python]
# generator_primary_energy_source_code                                      string[python]
# generator_prime_mover_code                                                string[python]
# generator_duct_burners                                                    string[python]
# sector                                                                    string[python]
# steam_plant_type                                                                   Int64
# relationship_type                                                         string[python]
# dtype: object

# %% [markdown]
# # 4. Persist SQL-Ready, 'Ground Truth' Dataset

# %%
from scripts.utils import save_df

# %%
# Save DataFrame
save_df(sql_df, "sql_ready_data.csv")
# Out:
# ✅ Saved: /Users/amyzhang/Documents/Projects_2026/eia_2.0/data_exports/sql_ready_data.csv
# PosixPath('/Users/amyzhang/Documents/Projects_2026/eia_2.0/data_exports/sql_ready_data.csv')
